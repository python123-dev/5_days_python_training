# %%
with open('demo.txt','w') as f:
    pass
print("file closed or not",f.closed)
# Out:
# file closed or not True

# %%
with open('t_text.txt','r') as f:
     f_contents = f.read()
     print(f_contents)
# Out:
# Welcome to python programming
# This is code to file handling
# Handling text
# Read text
# write text
# Append text

# %%
with open('t_text.txt','r') as f:
     f_contents = f.readlines()
     print(f_contents)
# Out:
# ['Welcome to python programming\n', 'This is code to file handling\n', 'Handling text\n', 'Read text\n', 'write text\n', 'Append text\n']

# %%
with open('t_text.txt','r') as f:
     f_contents = f.readline()
     print(f_contents)
     f_contents = f.readline()
     print(f_contents)
# Out:
# Welcome to python programming
#
# This is code to file handling

# %%
with open('t_text.txt','r') as f:
        f_contents = f.readline()
        print(f_contents, end = '')
        f_contents = f.readline()
        print(f_contents, end = '')
# Out:
# Welcome to python programming
# This is code to file handling

# %%
with open('t_text.txt','r') as f:
    for line in f:
        print(line, end = '')
# Out:
# Welcome to python programming
# This is code to file handling
# Handling text
# Read text
# write text
# Append text

# %%
with open('t_text.txt','r') as f:
    f_contents = f.read()
    print(f_contents, end = '')
# Out:
# Welcome to python programming
# This is code to file handling
# Handling text
# Read text
# write text
# Append text

# %%
with open('t_text.txt','r') as f:
    ###Printing by characters:
    f_contents = f.read(10)
    print(f_contents)
    '''f_contents = f.read(10)
    print(f_contents, end = '')
    f_contents = f.read(10)
    print(f_contents, end = '')'''
print(f.mode)
print(f.closed)
#print(f.read())
# Out:
# Welcome to
# r
# True

# %%
with open("test2.txt", "w") as f:
    
    f.write("Test")
    #f.seek(0)
    #tell()
	#f.write("Test")
	#f.seek("R")

# %%
with open("t_text.txt", "r") as rf:
    with open("test_copy.txt", "w") as wf:
        for line in rf:
            wf.write(line)

# %%
with open("t_text.txt", "r") as rf:
     f_contents = rf.read()
        
with open('test.txt','w') as wf:
    wf.write(f_contents)

# %%
words=open('t_text.txt').read()
print(words)
# Out:
# Welcome to python programming
# This is code to file handling
# Handling text
# Read text
# write text
# Append text
# welcome programming

# %%
import re
re.findall('^W.+g$',words)
# Out:
# []

# %%
re.findall('^W.+g$',words,re.M|re.I)
# Out:
# ['Welcome to python programming', 'welcome programming']

# %%
#
re.findall('''
^W    # string must start with w or W
.+    #Find some char in middle
g$    #end eith G or g
''',
          words,
          re.M|re.I|re.VERBOSE)#re.X
# Out:
# ['Welcome to python programming', 'welcome programming']

# %%
with open('website_data.txt','w') as f:
    pass
print("file closed or not",f.closed)
# Out:
# file closed or not True

# %%
import re

# File containing the text
file_path = "website_data.txt"

# Regex patterns
website_pattern = r'\b(?:https?://|www\.)\S+\b'
hashtag_pattern = r'#\w+'

# Lists to store websites and hashtags
websites = []
hashtags = []

# Reading the file and processing
with open(file_path, "r") as file:
    for line in file:
        # Find all websites and hashtags in the line
        websites.extend(re.findall(website_pattern, line))
        hashtags.extend(re.findall(hashtag_pattern, line))

# Print the results
print("Websites:", websites)
print("Hashtags:", hashtags)
# Out:
# Websites: ['https://www.example.com', 'www.newsportal.org', 'https://socialsite.com', 'https://resources.com', 'www.tools.net']
# Hashtags: ['#Learning', '#Python', '#Coding', '#Programming', '#Tech', '#Innovation', '#Tools', '#Development']
