# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\gauth\anaconda3\lib\site-packages (8.0.32)
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in c:\users\gauth\anaconda3\lib\site-packages (from mysql-connector-python) (3.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Structured-Traditional database(DBMS)->SQL
#Unstructured-mongodb->json->dictionary

# %%
import mysql.connector
# from mysql,connector import pooling

# mydb=pooling.mt(

# %%
mydb=mysql.connector.connect(
    host='127.0.0.1',   #ip address
    user='root',
    port=3377,                        #system name
    password=''         #
)

mycursor= mydb.cursor()

mycursor.execute('CREATE DATABASE mall')

# %%
mycursor.execute('SHOW DATABASES')

for x in mycursor:
    print(x)
# Out:
# ('e_calculator',)
# ('elderco',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('shop',)
# ('student',)
# ('test',)

# %%
mydb=mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
    database='shop'
)

mycursor= mydb.cursor()


mycursor.execute('CREATE TABLE customers (name VARCHAR(225),address VARCHAR(225))')

print('table created')
# Out:
# table created

# %%
mycursor.execute("ALTER TABLE customers ADD COLUMN id INT AUTO_INCREMENT PRIMARY KEY")

# %%
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = ("John", "Highway 21")
mycursor.execute(sql, val)

mydb.commit()

print(mycursor.rowcount, "record inserted.")
# Out:
# 1 record inserted.

# %%
sql = "INSERT INTO customers (name, address) VALUES (%s, %s)"
val = [
  ('Peter', 'Lowstreet 4'),
  ('Amy', 'Apple st 652'),
  ('Hannah', 'Mountain 21'),
  ('Michael', 'Valley 345'),
  ('Sandy', 'Ocean blvd 2'),
  ('Betty', 'Green Grass 1'),
  ('Richard', 'Sky st 331'),
  ('Susan', 'One way 98'),
  ('Vicky', 'Yellow Garden 2'),
  ('Ben', 'Park Lane 38'),
  ('William', 'Central st 954'),
  ('Chuck', 'Main Road 989'),
  ('Viola', 'Sideway 1633')
]

mycursor.executemany(sql, val)

mydb.commit()

print(mycursor.rowcount, "was inserted.")
# Out:
# 13 was inserted.

# %%
mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John', 'Highway 21', 1)
# ('Peter', 'Lowstreet 4', 2)
# ('Amy', 'Apple st 652', 3)
# ('Hannah', 'Mountain 21', 4)
# ('Michael', 'Valley 345', 5)
# ('Sandy', 'Ocean blvd 2', 6)
# ('Betty', 'Green Grass 1', 7)
# ('Richard', 'Sky st 331', 8)
# ('Susan', 'One way 98', 9)
# ('Vicky', 'Yellow Garden 2', 10)
# ('Ben', 'Park Lane 38', 11)
# ('William', 'Central st 954', 12)
# ('Chuck', 'Main Road 989', 13)
# ('Viola', 'Sideway 1633', 14)

# %%
mycursor.execute("SELECT name FROM customers")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('John',)
# ('Peter',)
# ('Amy',)
# ('Hannah',)
# ('Michael',)
# ('Sandy',)
# ('Betty',)
# ('Richard',)
# ('Susan',)
# ('Vicky',)
# ('Ben',)
# ('William',)
# ('Chuck',)
# ('Viola',)

# %%
sql = "SELECT * FROM customers WHERE address ='Park Lane 38'"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Ben', 'Park Lane 38', 11)

# %%
sql = "SELECT * FROM customers ORDER BY name"

mycursor.execute(sql)

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('Amy', 'Apple st 652', 3)
# ('Ben', 'Park Lane 38', 11)
# ('Betty', 'Green Grass 1', 7)
# ('Chuck', 'Main Road 989', 13)
# ('Hannah', 'Mountain 21', 4)
# ('John', 'Highway 21', 1)
# ('Michael', 'Valley 345', 5)
# ('Peter', 'Lowstreet 4', 2)
# ('Richard', 'Sky st 331', 8)
# ('Sandy', 'Ocean blvd 2', 6)
# ('Susan', 'One way 98', 9)
# ('Vicky', 'Yellow Garden 2', 10)
# ('Viola', 'Sideway 1633', 14)
# ('William', 'Central st 954', 12)

# %%
#delete a record
sql = "DELETE FROM customers WHERE address = 'Mountain 21'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) deleted")
# Out:
# 1 record(s) deleted

# %%
#update
sql = "UPDATE customers SET address = 'Canyon 123' WHERE address = 'Valley 345'"

mycursor.execute(sql)

mydb.commit()

print(mycursor.rowcount, "record(s) affected")
# Out:
# 1 record(s) affected
