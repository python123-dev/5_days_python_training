# %%
print("Hello World")
# Out:
# Hello World

# %%
#python identifiers
'''
A Python identifier is a user-defined name used to identify variables, 
functions, classes, modules, or other objects, following specific naming rules.
Valid:
name
_age
total_count
secondHighest

invalid:
1variable   # starts with a digit
my-variable # contains a hyphen
for         # keyword
my variable # contains a space

'''

# %%
#keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Correct indentation
if True:
    print("This is indented correctly")

# Incorrect indentation (will cause error)
# if True:
# print("This will cause an IndentationError")
# Out:
# This is indented correctly

# %%
# Implicit continuation
numbers = [
    1, 2, 3,
    4, 5, 6
]

# Explicit continuation
total = 1 + 2 + 3 + \
        4 + 5 + 6

print(numbers, total)
# Out:
# [1, 2, 3, 4, 5, 6] 21

# %%
#Quotes
single = 'Hello'
double = "World"
multi_line = """This is
a multi-line
string."""
print(single, double)
print(multi_line)
# Out:
# Hello World
# This is
# a multi-line
# string.

# %%
# Taking string input
name = input("Enter your name: ")

# Taking integer input with validation
try:
    age = int(input("Enter your age: "))
except ValueError:
    print("Invalid age entered.")
    age = None

print(f"Hello {name}, Age: {age}")
# Out:
# Enter your name:  abc
# Enter your age:  a1
# Invalid age entered.
# Hello abc, Age: None

# %%
name = "Alice"
age = 25
price = 99.99

x = 10
y = "Hello"
z = True

# %%
type(z)
# Out:
# bool

# %%
print(age+price)
# Out:
# 124.99

# %%
#multiple assignments
x, y, z = 1, 2, 3
print(x,y)

#Assign the same value to multiple variables
a=b=c=100

#swap without temp
x, y = y, x
print(x,y)
# Out:
# 1 2
# 2 1

# %%
#arithmetic operators
a = 7
b = 2

# addition
print ('Sum: ', a + b)  

# subtraction
print ('Subtraction: ', a - b)   

# multiplication
print ('Multiplication: ', a * b)  

# division
print ('Division: ', a / b) 

# floor division
print ('Floor Division: ', a // b)

# modulo
print ('Modulo: ', a % b)  

# a to the power b
print ('Power: ', a ** b)
# Out:
# Sum:  9
# Subtraction:  5
# Multiplication:  14
# Division:  3.5
# Floor Division:  3
# Modulo:  1
# Power:  49

# %%
#assignment operators
# assign 10 to a
a = 10

# assign 5 to b
b = 5 

# assign the sum of a and b to a
a += b      # a = a + b

print(a)

# Output: 15
# Out:
# 15

# %%
#comparison operators
a = 5

b = 2

# equal to operator
print('a == b =', a == b)

# not equal to operator
print('a != b =', a != b)

# greater than operator
print('a > b =', a > b)

# less than operator
print('a < b =', a < b)

# greater than or equal to operator
print('a >= b =', a >= b)

# less than or equal to operator
print('a <= b =', a <= b)
# Out:
# a == b = False
# a != b = True
# a > b = True
# a < b = False
# a >= b = True
# a <= b = False

# %%
#logical operators
# logical AND
print(True and True)     # True
print(True and False)    # False

# logical OR
print(True or False)     # True

# logical NOT
print(not True)          # False
# Out:
# True
# False
# True
# False

# %%
# Demonstrating Python Bitwise Operators

a = 5
b = 3

print(f"a = {a} ({bin(a)})")
print(f"b = {b} ({bin(b)})\n")

# AND
print(f"a & b  = {a & b} ({bin(a & b)})")

# OR
print(f"a | b  = {a | b} ({bin(a | b)})")

# XOR
print(f"a ^ b  = {a ^ b} ({bin(a ^ b)})")

# NOT
print(f"~a     = {~a} ({bin(~a)})")
print(f"~b     = {~b} ({bin(~b)})")

# Left Shift
print(f"a << 1 = {a << 1} ({bin(a << 1)})")

# Right Shift
print(f"a >> 1 = {a >> 1} ({bin(a >> 1)})")
# Out:
# a = 5 (0b101)
# b = 3 (0b11)
#
# a & b  = 1 (0b1)
# a | b  = 7 (0b111)
# a ^ b  = 6 (0b110)
# ~a     = -6 (-0b110)
# ~b     = -4 (-0b100)
# a << 1 = 10 (0b1010)
# a >> 1 = 2 (0b10)

# %%
#membership operators
message = 'Hello world'
dict1 = {1:'a', 2:'b'}

# check if 'H' is present in message string
print('H' in message)  # prints True

# check if 'hello' is present in message string
print('hello' not in message)  # prints True

# check if '1' key is present in dict1
print(1 in dict1)  # prints True

# check if 'a' key is present in dict1
print('a' in dict1)  # prints False
